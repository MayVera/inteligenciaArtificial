# %% [markdown]
# <a href="https://colab.research.google.com/github/MayVera/inteligenciaArtificial/blob/main/18deJulio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
print(pd.__version__)

serieData=pd.Series(data=[100,200,300],index=['Juan', 'Pedro', 'Lucas'])
print(serieData)
print('-----------------')
print(serieData['Pedro'])

print(serieData.index)
print('Pedro' in serieData)

myDictionary={'one':pd.Series([100,200,300], index=['Juan', 'Pedro', 'Lucas']),
              'two':pd.Series([11,22,33], index=['Julio', 'Pedro', 'Lucas'])}

# SERIES AND DATAFRAME

df=pd.DataFrame(myDictionary)
print(df)
print('-------------------------------------------------------------------------')
print(df.index)
print(df.columns)

print(df.loc['Pedro'])
print(df.iloc[2])
# Out:
# 2.0.3
# Juan     100
# Pedro    200
# Lucas    300
# dtype: int64
# -----------------
# 200
# Index(['Juan', 'Pedro', 'Lucas'], dtype='object')
# True
#          one   two
# Juan   100.0   NaN
# Julio    NaN  11.0
# Lucas  300.0  33.0
# Pedro  200.0  22.0
# -------------------------------------------------------------------------
# Index(['Juan', 'Julio', 'Lucas', 'Pedro'], dtype='object')
# Index(['one', 'two'], dtype='object')
# one    200.0
# two     22.0
# Name: Pedro, dtype: float64
# one    300.0
# two     33.0
# Name: Lucas, dtype: float64

# %%
import pandas as pd
df=pd.read_csv('/content/ratings.csv')

# %%
df
# Out:
#           userId  movieId  rating     timestamp
# 0              1    296.0     5.0  1.147880e+09
# 1              1    306.0     3.5  1.147869e+09
# 2              1    307.0     5.0  1.147869e+09
# 3              1    665.0     5.0  1.147879e+09
# 4              1    899.0     3.5  1.147869e+09
# ...          ...      ...     ...           ...
# 18935729  122803  97172.0     4.0  1.350867e+09
# 18935730  122803  97242.0     4.0  1.349921e+09
# 18935731  122803  97304.0     4.5  1.355007e+09
# 18935732  122803  97306.0     5.0  1.350264e+09
# 18935733    1228      NaN     NaN           NaN
#
# [18935734 rows x 4 columns]

# %%
df.get(3)

# %%
df.tail(6)
# Out:
#           userId  movieId  rating     timestamp
# 18935728  122803  96737.0     3.5  1.348377e+09
# 18935729  122803  97172.0     4.0  1.350867e+09
# 18935730  122803  97242.0     4.0  1.349921e+09
# 18935731  122803  97304.0     4.5  1.355007e+09
# 18935732  122803  97306.0     5.0  1.350264e+09
# 18935733    1228      NaN     NaN           NaN

# %%
del df['timestamp']

# %%
df
# Out:
#           userId  movieId  rating     timestamp
# 0              1    296.0     5.0  1.147880e+09
# 1              1    306.0     3.5  1.147869e+09
# 2              1    307.0     5.0  1.147869e+09
# 3              1    665.0     5.0  1.147879e+09
# 4              1    899.0     3.5  1.147869e+09
# ...          ...      ...     ...           ...
# 18935729  122803  97172.0     4.0  1.350867e+09
# 18935730  122803  97242.0     4.0  1.349921e+09
# 18935731  122803  97304.0     4.5  1.355007e+09
# 18935732  122803  97306.0     5.0  1.350264e+09
# 18935733    1228      NaN     NaN           NaN
#
# [18935734 rows x 4 columns]

# %%
df.shape
# Out:
# (18935734, 4)

# %%
df.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=18935734, step=1)

# %%
tmp=df.iloc[4]

# %%
tmp
# Out:
# userId       1.000000e+00
# movieId      8.990000e+02
# rating       3.500000e+00
# timestamp    1.147869e+09
# Name: 4, dtype: float64

# %%
tmp['userId']
# Out:
# 1.0

# %%
'rating' in df.columns
# Out:
# True

# %%
df.iloc[[100,200,300]]
# Out:
#      userId  movieId  rating     timestamp
# 100       2   1080.0     1.0  1.141416e+09
# 200       2   4886.0     5.0  1.141416e+09
# 300       3   1320.0     3.5  1.439475e+09

# %%
df.describe()
# Out:
#              userId       movieId        rating     timestamp
# count  1.893573e+07  1.893573e+07  1.893573e+07  1.893573e+07
# mean   6.147407e+04  2.140810e+04  3.533064e+00  1.215378e+09
# std    3.530966e+04  3.926027e+04  1.061291e+00  2.267012e+08
# min    1.000000e+00  1.000000e+00  5.000000e-01  7.896520e+08
# 25%    3.092400e+04  1.197000e+03  3.000000e+00  1.012720e+09
# 50%    6.156800e+04  2.947000e+03  3.500000e+00  1.197140e+09
# 75%    9.200800e+04  8.622000e+03  4.000000e+00  1.447174e+09
# max    1.228030e+05  2.091710e+05  5.000000e+00  1.574328e+09

# %%
min_rating = df['rating'].min()
max_rating = df['rating'].max()
mean_rating = df['rating'].mean()

print("Minimum rating:", min_rating)
print("Maximum rating:", max_rating)
print("Average rating:", mean_rating)
# Out:
# Minimum rating: 0.5
# Maximum rating: 5.0
# Average rating: 3.533063837560447

# %%
movies=pd.read_csv('/content/movies.csv')
ratings=pd.read_csv('/content/ratings.csv')
tags=pd.read_csv('/content/tags.csv')

# %%
ratings.head(2)
# Out:
#    userId  movieId  rating   timestamp
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817

# %%
movies.head(2)
# Out:
#    movieId             title                                       genres
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        2    Jumanji (1995)                   Adventure|Children|Fantasy

# %%
del ratings['timestamp']
del tags['timestamp']

# %%
print(movies.shape)
print(ratings.shape)
print(tags.shape)
# Out:
# (62423, 3)
# (19727837, 3)
# (1093360, 3)

# %%
movies.isnull().any()
# Out:
# movieId    False
# title      False
# genres     False
# dtype: bool

# %%
tags.isnull().any()
# Out:
# userId     False
# movieId    False
# tag         True
# dtype: bool

# %%
ratings.isnull().any()
# Out:
# userId     False
# movieId    False
# rating     False
# dtype: bool

# %%
print(tags.shape)
aux1=tags.shape[0]
tags=tags.dropna()
aux2=tags.shape[0]
print(aux1)
print(tags.shape)
print(f'Muestras eliminadas en variable tag',(aux1-aux2))
# Out:
# (1093360, 3)
# 1093360
# (1093344, 3)
# Muestras eliminadas en variable tag 16
