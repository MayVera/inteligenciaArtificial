# %% [markdown]
# <a href="https://colab.research.google.com/github/MayVera/inteligenciaArtificial/blob/main/18deJulio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
print(pd.__version__)

serieData=pd.Series(data=[100,200,300],index=['Juan', 'Pedro', 'Lucas'])
print(serieData)
print('-----------------')
print(serieData['Pedro'])

print(serieData.index)
print('Pedro' in serieData)

myDictionary={'one':pd.Series([100,200,300], index=['Juan', 'Pedro', 'Lucas']),
              'two':pd.Series([11,22,33], index=['Julio', 'Pedro', 'Lucas'])}

# SERIES AND DATAFRAME

df=pd.DataFrame(myDictionary)
print(df)
print('-------------------------------------------------------------------------')
print(df.index)
print(df.columns)

print(df.loc['Pedro'])
print(df.iloc[2])
# Out:
# 2.0.3
# Juan     100
# Pedro    200
# Lucas    300
# dtype: int64
# -----------------
# 200
# Index(['Juan', 'Pedro', 'Lucas'], dtype='object')
# True
#          one   two
# Juan   100.0   NaN
# Julio    NaN  11.0
# Lucas  300.0  33.0
# Pedro  200.0  22.0
# -------------------------------------------------------------------------
# Index(['Juan', 'Julio', 'Lucas', 'Pedro'], dtype='object')
# Index(['one', 'two'], dtype='object')
# one    200.0
# two     22.0
# Name: Pedro, dtype: float64
# one    300.0
# two     33.0
# Name: Lucas, dtype: float64

# %%
import pandas as pd
df=pd.read_csv('/content/ratings.csv')

# %%
df
# Out:
#           userId  movieId  rating     timestamp
# 0              1      296     5.0  1.147880e+09
# 1              1      306     3.5  1.147869e+09
# 2              1      307     5.0  1.147869e+09
# 3              1      665     5.0  1.147879e+09
# 4              1      899     3.5  1.147869e+09
# ...          ...      ...     ...           ...
# 14411641   93309      480     3.0  1.237605e+09
# 14411642   93309      527     5.0  1.237597e+09
# 14411643   93309      588     2.5  1.237603e+09
# 14411644   93309      593     5.0  1.237604e+09
# 14411645   93309      608     5.0           NaN
#
# [14411646 rows x 4 columns]

# %%
df.get(3)

# %%
df.tail(6)
# Out:
#         userId  movieId  rating     timestamp
# 494375    3397      780     3.0  1.058078e+09
# 494376    3397      784     2.0  1.058077e+09
# 494377    3397      785     3.0  1.058076e+09
# 494378    3397      788     3.5  1.058077e+09
# 494379    3397      832     2.5  1.058079e+09
# 494380    3397      836     NaN           NaN

# %%
del df['timestamp']

# %%
df
# Out:
#         userId  movieId  rating
# 0            1      296     5.0
# 1            1      306     3.5
# 2            1      307     5.0
# 3            1      665     5.0
# 4            1      899     3.5
# ...        ...      ...     ...
# 494376    3397      784     2.0
# 494377    3397      785     3.0
# 494378    3397      788     3.5
# 494379    3397      832     2.5
# 494380    3397      836     NaN
#
# [494381 rows x 3 columns]

# %%
df.shape
# Out:
# (494381, 3)

# %%
df.columns
# Out:
# Index(['userId', 'movieId', 'rating'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=494381, step=1)

# %%
tmp=df.iloc[4]

# %%
tmp
# Out:
# userId       1.0
# movieId    899.0
# rating       3.5
# Name: 4, dtype: float64

# %%
tmp['userId']
# Out:
# 1.0

# %%
'rating' in df.columns
# Out:
# True

# %%
df.iloc[[100,200,300]]
# Out:
#      userId  movieId  rating
# 100       2     1080     1.0
# 200       2     4886     5.0
# 300       3     1320     3.5

# %%
df.describe()
# Out:
#               userId        movieId         rating
# count  494381.000000  494381.000000  494380.000000
# mean     1726.321418   20719.658901       3.547029
# std       964.983143   38620.465316       1.056582
# min         1.000000       1.000000       0.500000
# 25%       891.000000    1136.000000       3.000000
# 50%      1748.000000    2795.000000       4.000000
# 75%      2537.000000    8128.000000       4.000000
# max      3397.000000  208939.000000       5.000000

# %%
min_rating = df['rating'].min()
max_rating = df['rating'].max()
mean_rating = df['rating'].mean()

print("Minimum rating:", min_rating)
print("Maximum rating:", max_rating)
print("Average rating:", mean_rating)
# Out:
# Minimum rating: 0.5
# Maximum rating: 5.0
# Average rating: 3.5470286014806423
